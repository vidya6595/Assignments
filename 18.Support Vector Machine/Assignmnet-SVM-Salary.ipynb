# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,roc_auc_score,precision_score,recall_score,confusion_matrix

# %% [markdown]
# ## Import Data

# %%
Salary_Test = pd.read_csv("SalaryData_Test(1).csv")
Salary_Test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
Salary_Train = pd.read_csv("SalaryData_Train(1).csv")
Salary_Train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
Salary_Test.shape,Salary_Train.shape
# Out:
# ((15060, 14), (30161, 14))

# %%
print(Salary_Test.dtypes)
print("\n",Salary_Train.dtypes)
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object
#
#  age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
Salary = pd.concat([Salary_Test,Salary_Train])
Salary
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 30156   27        Private     Assoc-acdm           12   Married-civ-spouse
# 30157   40        Private        HS-grad            9   Married-civ-spouse
# 30158   58        Private        HS-grad            9              Widowed
# 30159   22        Private        HS-grad            9        Never-married
# 30160   52   Self-emp-inc        HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0       Machine-op-inspct       Own-child   Black     Male            0
# 1         Farming-fishing         Husband   White     Male            0
# 2         Protective-serv         Husband   White     Male            0
# 3       Machine-op-inspct         Husband   Black     Male         7688
# 4           Other-service   Not-in-family   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            50   United-States   <=50K
# 2                0            40   United-States    >50K
# 3                0            40   United-States    >50K
# 4                0            30   United-States   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [45221 rows x 14 columns]

# %% [markdown]
# ## Data Understanding

# %%
Salary.shape
# Out:
# (45221, 14)

# %%
Salary.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
Salary.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
Salary.describe(include='all')
# Out:
#                  age workclass education   educationno        maritalstatus  \
# count   45221.000000     45221     45221  45221.000000                45221
# unique           NaN         7        16           NaN                    7
# top              NaN   Private   HS-grad           NaN   Married-civ-spouse
# freq             NaN     33306     14783           NaN                21055
# mean       38.548086       NaN       NaN     10.118463                  NaN
# std        13.217981       NaN       NaN      2.552909                  NaN
# min        17.000000       NaN       NaN      1.000000                  NaN
# 25%        28.000000       NaN       NaN      9.000000                  NaN
# 50%        37.000000       NaN       NaN     10.000000                  NaN
# 75%        47.000000       NaN       NaN     13.000000                  NaN
# max        90.000000       NaN       NaN     16.000000                  NaN
#
#            occupation relationship    race    sex   capitalgain   capitalloss  \
# count           45221        45221   45221  45221  45221.000000  45221.000000
# unique             14            6       5      2           NaN           NaN
# top      Craft-repair      Husband   White   Male           NaN           NaN
# freq             6020        18666   38902  30527           NaN           NaN
# mean              NaN          NaN     NaN    NaN   1101.454700     88.548617
# std               NaN          NaN     NaN    NaN   7506.511295    404.838249
# min               NaN          NaN     NaN    NaN      0.000000      0.000000
# 25%               NaN          NaN     NaN    NaN      0.000000      0.000000
# 50%               NaN          NaN     NaN    NaN      0.000000      0.000000
# 75%               NaN          NaN     NaN    NaN      0.000000      0.000000
# max               NaN          NaN     NaN    NaN  99999.000000   4356.000000
#
#         hoursperweek          native  Salary
# count   45221.000000           45221   45221
# unique           NaN              40       2
# top              NaN   United-States   <=50K
# freq             NaN           41292   34013
# mean       40.938038             NaN     NaN
# std        12.007640             NaN     NaN
# min         1.000000             NaN     NaN
# 25%        40.000000             NaN     NaN
# 50%        40.000000             NaN     NaN
# 75%        45.000000             NaN     NaN
# max        99.000000             NaN     NaN

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## Data set has 2 columns refering to Education so can delete one and do necessary transformation

# %%
del Salary['educationno']

# %%
Salary.shape
# Out:
# (45221, 13)

# %%
Salary
# Out:
#        age      workclass      education        maritalstatus  \
# 0       25        Private           11th        Never-married
# 1       38        Private        HS-grad   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm   Married-civ-spouse
# 3       44        Private   Some-college   Married-civ-spouse
# 4       34        Private           10th        Never-married
# ...    ...            ...            ...                  ...
# 30156   27        Private     Assoc-acdm   Married-civ-spouse
# 30157   40        Private        HS-grad   Married-civ-spouse
# 30158   58        Private        HS-grad              Widowed
# 30159   22        Private        HS-grad        Never-married
# 30160   52   Self-emp-inc        HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0       Machine-op-inspct       Own-child   Black     Male            0
# 1         Farming-fishing         Husband   White     Male            0
# 2         Protective-serv         Husband   White     Male            0
# 3       Machine-op-inspct         Husband   Black     Male         7688
# 4           Other-service   Not-in-family   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            50   United-States   <=50K
# 2                0            40   United-States    >50K
# 3                0            40   United-States    >50K
# 4                0            30   United-States   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [45221 rows x 13 columns]

# %%
le = LabelEncoder()
Salary['workclass'] = le.fit_transform(Salary.workclass)
Salary['education'] = le.fit_transform(Salary.education)
Salary['maritalstatus'] = le.fit_transform(Salary.maritalstatus)
Salary['relationship'] = le.fit_transform(Salary.relationship)
Salary['sex'] = le.fit_transform(Salary.sex)
Salary['race'] = le.fit_transform(Salary.race)
Salary['native'] = le.fit_transform(Salary.native)
Salary['Salary'] = le.fit_transform(Salary.Salary)
Salary['occupation'] = le.fit_transform(Salary.occupation)

# %%
Salary
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       25          2          1              4           6             3
# 1       38          2         11              2           4             0
# 2       28          1          7              2          10             0
# 3       44          2         15              2           6             0
# 4       34          2          0              4           7             1
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native  Salary
# 0         2    1            0            0            40      37       0
# 1         4    1            0            0            50      37       0
# 2         4    1            0            0            40      37       1
# 3         2    1         7688            0            40      37       1
# 4         4    1            0            0            30      37       0
# ...     ...  ...          ...          ...           ...     ...     ...
# 30156     4    0            0            0            38      37       0
# 30157     4    1            0            0            40      37       1
# 30158     4    0            0            0            40      37       0
# 30159     4    1            0            0            20      37       0
# 30160     4    0        15024            0            40      37       1
#
# [45221 rows x 13 columns]

# %%
Salary.dtypes,Salary.shape
# Out:
# (age              int64
#  workclass        int32
#  education        int32
#  maritalstatus    int32
#  occupation       int32
#  relationship     int32
#  race             int32
#  sex              int32
#  capitalgain      int64
#  capitalloss      int64
#  hoursperweek     int64
#  native           int32
#  Salary           int32
#  dtype: object,
#  (45221, 13))

# %% [markdown]
# ## Model Building

# %%
X = Salary.drop('Salary',axis=1)
y = Salary['Salary']

# %%
X
# Out:
#        age  workclass  education  maritalstatus  occupation  relationship  \
# 0       25          2          1              4           6             3
# 1       38          2         11              2           4             0
# 2       28          1          7              2          10             0
# 3       44          2         15              2           6             0
# 4       34          2          0              4           7             1
# ...    ...        ...        ...            ...         ...           ...
# 30156   27          2          7              2          12             5
# 30157   40          2         11              2           6             0
# 30158   58          2         11              6           0             4
# 30159   22          2         11              4           0             3
# 30160   52          3         11              2           3             5
#
#        race  sex  capitalgain  capitalloss  hoursperweek  native
# 0         2    1            0            0            40      37
# 1         4    1            0            0            50      37
# 2         4    1            0            0            40      37
# 3         2    1         7688            0            40      37
# 4         4    1            0            0            30      37
# ...     ...  ...          ...          ...           ...     ...
# 30156     4    0            0            0            38      37
# 30157     4    1            0            0            40      37
# 30158     4    0            0            0            40      37
# 30159     4    1            0            0            20      37
# 30160     4    0        15024            0            40      37
#
# [45221 rows x 12 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 30156    0
# 30157    1
# 30158    0
# 30159    0
# 30160    1
# Name: Salary, Length: 45221, dtype: int32

# %%
X.shape,y.shape
# Out:
# ((45221, 12), (45221,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=15,stratify = y)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((36176, 12), (9045, 12), (36176,), (9045,))

# %% [markdown]
# ## Model Training without Scaling | Model Testing | Model Evaluation

# %% [markdown]
# ## Kernel = rbf

# %%
svc_classifier = SVC(kernel='rbf')
svc_classifier.fit(X_train,y_train)
y_pred = svc_classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 2416     0
# 23470    0
# 7982     0
# 15816    1
# 6392     0
#         ..
# 14334    0
# 1027     1
# 5250     0
# 1016     0
# 22248    1
# Name: Salary, Length: 9045, dtype: int32

# %%
print("Overall Accuracy : ",round(accuracy_score(y_test,y_pred),4))
print("Precision        : ",round(precision_score(y_test,y_pred),4))
print("Recall           : ",round(recall_score(y_test,y_pred),4))
print("AUC Score        : ",round(roc_auc_score(y_test,y_pred),4))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
print("Confusion Matrix :")

plt.figure(figsize = (8,6))
confu_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(data = confu_matrix,
            annot=True,
            linewidths=0.8,
            fmt='g'
            )
plt.xlabel("Prediction")
plt.ylabel("Actual labels")
plt.title("Prediction Vs Actual",size = 20)
# Out:
# Overall Accuracy :  0.798
# Precision        :  0.7578
# Recall           :  0.2721
# AUC Score        :  0.6217
# Confusion Matrix :
#  [[6608  195]
#  [1632  610]]
# Confusion Matrix :
# Text(0.5, 1, 'Prediction Vs Actual')

# %% [markdown]
# ## kernel = polynomial

# %%
svc_classifier = SVC(kernel='poly',degree=1)
svc_classifier.fit(X_train,y_train)
y_pred = svc_classifier.predict(X_test)

print("Overall Accuracy : ",round(accuracy_score(y_test,y_pred),4))
print("Precision        : ",round(precision_score(y_test,y_pred),4))
print("Recall           : ",round(recall_score(y_test,y_pred),4))
print("AUC Score        : ",round(roc_auc_score(y_test,y_pred),4))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred))
print("Confusion Matrix :")

plt.figure(figsize = (8,6))
confu_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(data = confu_matrix,
            annot=True,
            linewidths=0.8,
            fmt='g'
            )
plt.xlabel("Prediction")
plt.ylabel("Actual labels")
plt.title("Prediction Vs Actual",size = 20)
# Out:
# Overall Accuracy :  0.7933
# Precision        :  0.6954
# Recall           :  0.2953
# AUC Score        :  0.6263
# Confusion Matrix :
#  [[6513  290]
#  [1580  662]]
# Confusion Matrix :
# Text(0.5, 1, 'Prediction Vs Actual')

# %% [markdown]
# ## Model training with scaling | Model Testing | Model Evaluation

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)
x_scaled
# Out:
# array([[-1.02498531, -0.21344557, -2.43996316, ..., -0.21872833,
#         -0.07812093,  0.26444339],
#        [-0.04146565, -0.21344557,  0.17992971, ..., -0.21872833,
#          0.75469138,  0.26444339],
#        [-0.79801924, -1.25715468, -0.86802744, ..., -0.21872833,
#         -0.07812093,  0.26444339],
#        ...,
#        [ 1.47164153, -0.21344557,  0.17992971, ..., -0.21872833,
#         -0.07812093,  0.26444339],
#        [-1.25195139, -0.21344557,  0.17992971, ..., -0.21872833,
#         -1.74374555,  0.26444339],
#        [ 1.01770937,  0.83026355,  0.17992971, ..., -0.21872833,
#         -0.07812093,  0.26444339]])

# %%
X_train_scaled,X_test_scaled,y_train_scaled,y_test_scaled = train_test_split(x_scaled,y,test_size=0.20,random_state=15,stratify = y)
X_train_scaled.shape,X_test_scaled.shape,y_train_scaled.shape,y_test_scaled.shape
# Out:
# ((36176, 12), (9045, 12), (36176,), (9045,))

# %% [markdown]
# ## kernel = rbf

# %%
svc_classifier = SVC(kernel='rbf')
svc_classifier.fit(X_train_scaled,y_train_scaled)
y_pred_scaled = svc_classifier.predict(X_test_scaled)

print("Overall Accuracy : ",round(accuracy_score(y_test,y_pred_scaled),4))
print("Precision        : ",round(precision_score(y_test,y_pred_scaled),4))
print("Recall           : ",round(recall_score(y_test,y_pred_scaled),4))
print("AUC Score        : ",round(roc_auc_score(y_test,y_pred_scaled),4))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred_scaled))
print("Confusion Matrix :")

plt.figure(figsize = (8,6))
confu_matrix = confusion_matrix(y_test,y_pred_scaled)
sns.heatmap(data = confu_matrix,
            annot=True,
            linewidths=0.8,
            fmt='g'
            )
plt.xlabel("Prediction")
plt.ylabel("Actual labels")
plt.title("Prediction Vs Actual",size = 20)
# Out:
# Overall Accuracy :  0.8251
# Precision        :  0.7527
# Recall           :  0.4384
# AUC Score        :  0.6955
# Confusion Matrix :
#  [[6480  323]
#  [1259  983]]
# Confusion Matrix :
# Text(0.5, 1, 'Prediction Vs Actual')

# %% [markdown]
# ## kernel = Polynomial

# %%
svc_classifier = SVC(kernel='poly',degree=1)
svc_classifier.fit(X_train_scaled,y_train_scaled)
y_pred_scaled = svc_classifier.predict(X_test_scaled)

print("Overall Accuracy : ",round(accuracy_score(y_test,y_pred_scaled),4))
print("Precision        : ",round(precision_score(y_test,y_pred_scaled),4))
print("Recall           : ",round(recall_score(y_test,y_pred_scaled),4))
print("AUC Score        : ",round(roc_auc_score(y_test,y_pred_scaled),4))
print('Confusion Matrix :\n',confusion_matrix(y_test,y_pred_scaled))
print("Confusion Matrix :")

plt.figure(figsize = (8,6))
confu_matrix = confusion_matrix(y_test,y_pred_scaled)
sns.heatmap(data = confu_matrix,
            annot=True,
            linewidths=0.8,
            fmt='g'
            )
plt.xlabel("Prediction")
plt.ylabel("Actual labels")
plt.title("Prediction Vs Actual",size = 20)
# Out:
# Overall Accuracy :  0.7933
# Precision        :  0.6954
# Recall           :  0.2953
# AUC Score        :  0.6263
# Confusion Matrix :
#  [[6513  290]
#  [1580  662]]
# Confusion Matrix :
# Text(0.5, 1, 'Prediction Vs Actual')

# %% [markdown]
# ## From above we can observe
# ### With kernel - rbf
# * Accuracy without Scaling = 79.80%
# * Accuracy with Scaling = 82.51%
#
# ### With kernel - polynomial
# * Accuracy without Scaling = 79.33%
# * Accuracy with Scaling = 79.33%
#
# ### Lets imporve accuracy by tweaking the hyperparameter

# %%
def generate_clf(input_gamma, input_C=1):
    classifier = SVC(kernel="rbf", gamma=input_gamma, C=input_C)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    print("Training Accuracy = {}".format(accuracy_score(y_pred, y_test)))
    return classifier

# %% [markdown]
# ### Classifier_1 Gamma = 0.001

# %%
Classifier_1 = generate_clf(0.001)
# Out:
# Training Accuracy = 0.8249861802100608

# %% [markdown]
# ### Classifier_2 Gamma = 0.01

# %%
Classifier_2 = generate_clf(0.01)
# Out:
# Training Accuracy = 0.8311774461028192

# %% [markdown]
# ### Classifier 3 Gamma = 0.1

# %%
Classifier_3 = generate_clf(0.1)
# Out:
# Training Accuracy = 0.807739082365948

# %% [markdown]
# ### Classifier 4 Gamma = 1

# %%
Classifier_4 = generate_clf(1)
# Out:
# Training Accuracy = 0.7635157545605307

# %% [markdown]
# ### Classifier 5 Gamma = 0.1 & C = 0.1

# %%
Classifier_5 = generate_clf(0.1,0.1)
# Out:
# Training Accuracy = 0.7593145384190161

# %% [markdown]
# ### Classifier 6 Gamma = 0.1 & C = 1

# %%
Classifier_6 = generate_clf(0.1,1)
# Out:
# Training Accuracy = 0.807739082365948

# %% [markdown]
# ### Classifier 7 Gamma = 0.1 & C = 10

# %%
Classifier_7 = generate_clf(0.1,10)
# Out:
# Training Accuracy = 0.7970149253731343

# %% [markdown]
# ## From above observation Classifier_2 giving more accuracy ,There Best model is Kernel = rbf , Gamma = 0.01

# %% [markdown]
# ## Heat Map

# %%
print("Confusion Matrix :")

plt.figure(figsize = (8,6))
confu_matrix = confusion_matrix(y_test,y_pred_scaled)
sns.heatmap(data = confu_matrix,
            annot=True,
            linewidths=0.8,
            fmt='g'
            xticklabels=('<=50K','>50k'),
            yticklabels=('<=50K','>50k'),
            )
plt.xlabel("Prediction")
plt.ylabel("Actual labels")
plt.title("Prediction Vs Actual",size = 20)
